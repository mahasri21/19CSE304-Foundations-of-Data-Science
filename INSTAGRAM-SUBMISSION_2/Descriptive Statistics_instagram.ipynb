# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/train.csv")
df
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
df.sort_values(by=["profile pic"])
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 430            0                  0.09               1                  0.00
# 409            0                  0.38               1                  0.00
# 408            0                  0.21               1                  0.00
# 407            0                  0.42               1                  0.00
# 405            0                  0.21               1                  0.00
# ..           ...                   ...             ...                   ...
# 192            1                  0.00               2                  0.00
# 193            1                  0.00               4                  0.25
# 194            1                  0.00               1                  0.33
# 188            1                  0.00               2                  0.00
# 575            1                  0.27               1                  0.00
#
# ...

# %%
df.groupby(['private']).mean()
# Out:
#          profile pic  nums/length username  fullname words  \
# private
# 0           0.660112              0.174551        1.533708
# 1           0.768182              0.146500        1.340909
#
#          nums/length fullname  name==username  description length  \
# private
# 0                    0.039045        0.028090           25.890449
# 1                    0.031318        0.045455           17.336364
#
#          external URL      #posts     #followers    #follows      fake
# private
# 0            0.157303  135.117978  137829.969101  549.870787  0.511236
# 1            0.050000   62.781818     315.904545  441.245455  0.481818

# %%
temp_df1 = df[[ "private", "fullname words"]]
temp_df2 = df[["description length", "nums/length username" ,"private"]]
temp_df = pd.merge(temp_df1, temp_df2)
temp_df
# Out:
#         private  fullname words  description length  nums/length username
# 0             0               0                  53                  0.27
# 1             0               0                  44                  0.00
# 2             0               0                  82                  0.00
# 3             0               0                  81                  0.00
# 4             0               0                  50                  0.00
# ...         ...             ...                 ...                   ...
# 175131        1               1                   0                  0.19
# 175132        1               1                   0                  0.46
# 175133        1               1                   0                  0.00
# 175134        1               1                   0                  0.62
# 175135        1               1                   0                  0.25
#
# [175136 rows x 4 columns]

# %%
df.fillna(method='bfill')
# Out:
#      profile pic  nums/length username  fullname words  nums/length fullname  \
# 0              1                  0.27               0                  0.00
# 1              1                  0.00               2                  0.00
# 2              1                  0.10               2                  0.00
# 3              1                  0.00               1                  0.00
# 4              1                  0.00               2                  0.00
# ..           ...                   ...             ...                   ...
# 571            1                  0.55               1                  0.44
# 572            1                  0.38               1                  0.33
# 573            1                  0.57               2                  0.00
# 574            1                  0.57               1                  0.00
# 575            1                  0.27               1                  0.00
#
# ...
